# %%
# Step 1: Read the dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
iris = sns.load_dataset("iris")

# %%
# Step 2: Display the columns
print("Columns in the dataset:")
print(iris.columns)
# Out:
# Columns in the dataset:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# Step 3: Calculate the mean of each column
column_means = iris.mean()
print("\nMean of each column:")
print(column_means)
# Out:
# Mean of each column:
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64
# <ipython-input-6-5a9498d87688>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   column_means = iris.mean()

# %%
# Step 4: Check for null values
null_values = iris.isnull().sum()
print("\nNull values in the dataset:")
print(null_values)
# Out:
# Null values in the dataset:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Step 5: Perform meaningful visualizations
# Visualization 1: Pairplot
sns.pairplot(iris, hue="species")
plt.title("Pairplot of Iris Dataset")
plt.show()

# %%
# Visualization 2: Boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x="species", y="sepal_length", data=iris)
plt.title("Boxplot of Sepal Length by Species")
plt.show()

# %%
# Visualization 3: Violinplot
plt.figure(figsize=(10, 6))
sns.violinplot(x="species", y="petal_width", data=iris)
plt.title("Violinplot of Petal Width by Species")
plt.show()
